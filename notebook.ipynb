# %% [markdown]
# # Installation env de dev

# %%
# !python -m venv .mia_front

# %%
pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/44.3 kB ? eta -:--:--
#      ---------------------------------------- 44.3/44.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.1 MB 15.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/9.1 MB 26.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.3/9.1 MB 39.0 MB/s eta 0:00:01
#    --------------------------------- ------ 7.7/9.1 MB 44.8 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.1 MB 44.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 36.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
# ...

# %%
python -m streamlit run accueil.py --server.port 5000
